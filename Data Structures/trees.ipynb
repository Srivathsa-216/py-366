# %%
class TreeNode:
    
    def __init__(self,data):
        self.data = data
        self.children = []
        self.parent = None
        
    def add_child(self,child):
        child.parent = self
        self.children.append(child)
        
    def get_level(self):
        level = 0
        p = self.parent
        while p:
            level += 1
            p = p.parent
            
        return level
        
    def print_tree(self):
        spaces = ' ' * self.get_level() * 4
        prefix = spaces + "|__" if self.parent else ""
        print(prefix + self.data)
        if self.children:
            for child in self.children:
                child.print_tree()

# %%
def build_product_tree():
    root = TreeNode("Electronics")
    
    laptop = TreeNode("laptop")
    laptop.add_child(TreeNode("DELL"))
    laptop.add_child(TreeNode("HP"))
    laptop.add_child(TreeNode("JIO"))
    
    smartphone = TreeNode('smartPhone')
    smartphone.add_child(TreeNode("Moto"))
    smartphone.add_child(TreeNode("Samsung"))
    smartphone.add_child(TreeNode("Redmi"))
    
    gadget = TreeNode('gadget')
    gadget.add_child(TreeNode("smartWatch"))
    gadget.add_child(TreeNode("Joystick"))
    
    root.add_child(laptop)
    root.add_child(smartphone)
    root.add_child(gadget)

    
    return root

# %%
root = build_product_tree()

# %%
root.print_tree()
# Out:
# Electronics
#     |__laptop
#         |__DELL
#         |__HP
#         |__JIO
#     |__smartPhone
#         |__Moto
#         |__Samsung
#         |__Redmi
#     |__gadget
#         |__smartWatch
#         |__Joystick

# %%
child = TreeNode(root.children)

# %%
child.get_level()
# Out:
# 0

# %% [markdown]
# # General Tree
# Below is the management hierarchy of a company.
#
# ![image.png](attachment:image.png)
#
# Extent tree class built in our main tutorial so that it takes name and designation in data part of TreeNode class. Now extend print_tree function such that it can print either name tree, designation tree or name and designation tree. As shown below,
#
# ![image-2.png](attachment:image-2.png)
#
# Here is how your main function should will look like,
#
# if __name__ == '__main__':
#     root_node = build_management_tree()
#     root_node.print_tree("name") # prints only name hierarchy
#     root_node.print_tree("designation") # prints only designation hierarchy
#     root_node.print_tree("both") # prints both (name and designation) hierarchy

# %%
class TreeNode:
    
    def __init__(self,data):
        self.data = data
        self.children = []
        self.parent = None
        
    def add_child(self,child):
        child.parent = self
        self.children.append(child)
        
    def get_level(self):
        level = 0
        p = self.parent
        while p:
            level += 1
            p = p.parent
            
        return level
        
    def print_tree(self,choice):
        if choice == "name":
            self = self.children[1]
        elif choice == "designation":
            self = self.children[0] 
        spaces = ' ' * self.get_level() * 4
        prefix = spaces + "|__" if self.parent.parent else ""
        print(prefix + self.data)
        if self.children:
            for child in self.children:
                child.print_tree("")

# %%
def build_product_tree():
    Company = TreeNode("Company")
    CEO =  TreeNode("CEO")
    Nilpul = TreeNode("Nilpul")
    
    HR_HEAD = TreeNode('HR HEAD')
    HR_HEAD.add_child(TreeNode("Recruitment Manager"))
    HR_HEAD.add_child(TreeNode("Policy Manager"))
    
    CTO = TreeNode("CTO")
    
    INFRASTRUCTURE_HEAD = TreeNode('INFRASTRUCTURE HEAD')
    INFRASTRUCTURE_HEAD.add_child(TreeNode("Cloud Manager"))
    INFRASTRUCTURE_HEAD.add_child(TreeNode("App Manager"))
    CTO.add_child(INFRASTRUCTURE_HEAD)
    CTO.add_child(TreeNode("APPLICATION HEAD"))   
    
    Gels = TreeNode('Gels')
    Gels.add_child(TreeNode("Peter"))
    Gels.add_child(TreeNode("Waqas"))
    
    Vishwa = TreeNode('Vishwa')
    Vishwa.add_child(TreeNode("Dhaval"))
    Vishwa.add_child(TreeNode("Abhijit"))
    
    Chinmay = TreeNode("Chinmay")
    Chinmay.add_child(Vishwa)
    Chinmay.add_child(TreeNode('Aamir'))
    
    Nilpul.add_child(Chinmay)
    Nilpul.add_child(Gels)
    CEO.add_child(CTO)
    CEO.add_child(HR_HEAD)
    Company.add_child(CEO)
    Company.add_child(Nilpul)
    
    return Company

# %%
Company = build_product_tree()
Company.print_tree("designation")
# Out:
# CEO
#         |__CTO
#             |__INFRASTRUCTURE HEAD
#                 |__Cloud Manager
#                 |__App Manager
#             |__APPLICATION HEAD
#         |__HR HEAD
#             |__Recruitment Manager
#             |__Policy Manager
