# %% [markdown]
# ---
#
# Load libraries
#
# ---

# %%
## Load libraries
import numpy as np
import sympy as sp
import sys
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.style.use('dark_background')
from keras.datasets import mnist
# %matplotlib inline

# %% [markdown]
# ---
#
# Set printing precision
#
# ---

# %%
np.set_printoptions(precision = 2)

# %% [markdown]
# ---
#
# Import tensorflow and check version
#
# ---

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.15.0'

# %%
## Mount Google drive folder if running in Colab
if('google.colab' in sys.modules):
    from google.colab import drive
    drive.mount('/content/drive', force_remount = True)
    DIR = '/content/drive/MyDrive/Learning/Data Science/Deep Learning/OneDrive-2024-04-01'
    DATA_DIR = DIR + '/Data/'
else:
    DATA_DIR = 'Data/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---
#
# Calculating softmax loss and gradient for a toy dataset
#
# ----

# %%
# Generate artificial data with 5 samples, 4 features per sample
# and 3 output classes
num_samples = 5 # number of samples
num_features = 4 # number of features (a.k.a. dimensionality)
num_labels = 3 # number of output labels
# Data matrix (each column = single sample)
X = np.random.choice(np.arange(0, 5), size = (num_features, num_samples), replace = True)
# Class labels
y = np.random.choice([0, 1, 2], size = num_samples, replace = True)
# Randomly assign entries of weights matrix
W = np.random.choice(np.arange(-4, 4), size = (num_labels, num_features), replace = True)
print('X = ')
print(X)
print('y = ')
print(y)
print('W = ')
print(W)
# Out:
# X =
# [[4 0 4 4 3]
#  [1 2 0 2 2]
#  [1 3 0 1 1]
#  [3 4 1 1 2]]
# y =
# [0 2 0 1 0]
# W =
# [[ 2 -1 -3 -2]
#  [ 0  2  2 -4]
#  [ 0 -4  0  3]]

# %% [markdown]
# ---
#
# Add the bias feature to the data matrix (run this cell only once!)
#
# ---

# %%
# Add the bias feature to the data matrix (run this cell only once!)
print('X = ')
print(X)
print('X with bias feature = ')
X = np.vstack([X, np.ones((1, num_samples))])
print(X)
# Out:
# X =
# [[4 0 4 4 3]
#  [1 2 0 2 2]
#  [1 3 0 1 1]
#  [3 4 1 1 2]]
# X with bias feature =
# [[4. 0. 4. 4. 3.]
#  [1. 2. 0. 2. 2.]
#  [1. 3. 0. 1. 1.]
#  [3. 4. 1. 1. 2.]
#  [1. 1. 1. 1. 1.]]

# %% [markdown]
# ---
#
# Adjust the weight matrix with (possibly random) values added
# for bias as the last column (run this cell only once!)
#
# ---

# %%
# Adjust the weight matrix with (possibly random) values added
# for bias as the last column (run this cell only once!)
W = np.hstack([W, np.ones((num_labels, 1))])
print(W)
# Out:
# [[ 2. -1. -3. -2.  1.]
#  [ 0.  2.  2. -4.  1.]
#  [ 0. -4.  0.  3.  1.]]

# %% [markdown]
# ---
#
# Calculate the raw zcores matrix
#
# ---

# %%
Z = np.dot(W, X)
print('Z = ')
print(Z)
# Out:
# Z =
# [[ -1. -18.   7.   2.  -2.]
#  [ -7.  -5.  -3.   3.  -1.]
#  [  6.   5.   4.  -4.  -1.]]

# %%
print(y)
# Out:
# [0 2 0 1 0]

# %% [markdown]
# ---
#
# Define softmax function
#
# ---

# %%
# Define softmax function
def softmax(Z):
  # Convert scores to non-normalized probabilites matrix. Note that for each sample,
  # that is in each column, the values don't add up to 1. Also note that the
  # output values are typically large or small
  Z_exp = np.exp(Z - np.max(Z, axis = 0))
  # Normalize probabilities matrix such that the sum across each column is equal to 1.
  # Now we have actually probability values for each sample.
  return(Z_exp / np.sum(Z_exp, axis = 0))

# %% [markdown]
# ---
#
# Calculate the probability matrix
#
# ---

# %%
#  Calculate the probability matrix
P = softmax(Z)
print(Z)
print(P)
# Sum in each column of matrix P
print(np.sum(P, axis = 0))
# Print the correct label for each sample
print(y)
# Out:
# [[ -1. -18.   7.   2.  -2.]
#  [ -7.  -5.  -3.   3.  -1.]
#  [  6.   5.   4.  -4.  -1.]]
# [[9.11e-04 1.03e-10 9.53e-01 2.69e-01 1.55e-01]
#  [2.26e-06 4.54e-05 4.32e-05 7.31e-01 4.22e-01]
#  [9.99e-01 1.00e+00 4.74e-02 6.66e-04 4.22e-01]]
# [1. 1. 1. 1. 1.]
# [0 2 0 1 0]

# %% [markdown]
# ---
#
# Calculate training loss for all samples.
#
# ---

# %%
loss = -np.log(P[y, np.arange(num_samples)])
print('Loss = ')
print(loss)
# Calculate average training loss
loss_data = np.mean(loss)
print('Total loss = %f'%(loss_data))
# Out:
# Loss =
# [7.00e+00 4.54e-05 4.86e-02 3.14e-01 1.86e+00]
# Total loss = 1.845103

# %% [markdown]
# ---
#
# Calculate regularization loss
#
# ---

# %%
print(W)
print(W[:, :-1])
print(W[:, :-1] * W[:, :-1])
# Out:
# [[ 2. -1. -3. -2.  1.]
#  [ 0.  2.  2. -4.  1.]
#  [ 0. -4.  0.  3.  1.]]
# [[ 2. -1. -3. -2.]
#  [ 0.  2.  2. -4.]
#  [ 0. -4.  0.  3.]]
# [[ 4.  1.  9.  4.]
#  [ 0.  4.  4. 16.]
#  [ 0. 16.  0.  9.]]

# %%
# Regularization loss
reg = 0.1 # strength of regularization = 10%
loss_reg = np.sum(W[:, :-1] * W[:, :-1])
print('Total loss = %f'%(loss_data + reg * loss_reg))
# Out:
# Total loss = 8.545103

# %% [markdown]
# ---
#
# Calculate the gradient of total loss w.r.t. the weights W
#
# ---

# %%
# Adjust the probability matrix such that 1 is subtracted
# from each samples correct category probability.
P[y, range(num_samples)] = P[y, range(num_samples)]  - 1

# Calculate the gradient of total loss w.r.t. the weights W
dW =(1/num_samples)*np.dot(P, X.T) + reg * 2 * np.hstack([W[:, :-1], np.zeros((num_labels, 1))])
print(dW)
# Out:
# [[-0.73 -0.63 -0.91 -1.29 -0.32]
#  [ 0.04  0.46  0.43 -0.68  0.03]
#  [ 1.09 -0.43  0.28  1.38  0.29]]

# %% [markdown]
# ---
#
# Apply gradient descent to the toy dataset
#
# ---

# %%
alpha = 1e-02 # learning rate
tol = 1e-05 # stopping tolerance
iter = 0
maxiter = 1000

while np.linalg.norm(dW) > tol and iter < maxiter:
  W = W + alpha * (-dW)
  iter = iter+1
  print('Iteration = %d, ||gradL(W)|| = %f'%(iter, np.linalg.norm(dW)))
# Out:
# Iteration = 1, ||gradL(W)|| = 2.802677
# Iteration = 2, ||gradL(W)|| = 2.802677
# Iteration = 3, ||gradL(W)|| = 2.802677
# Iteration = 4, ||gradL(W)|| = 2.802677
# Iteration = 5, ||gradL(W)|| = 2.802677
# Iteration = 6, ||gradL(W)|| = 2.802677
# Iteration = 7, ||gradL(W)|| = 2.802677
# Iteration = 8, ||gradL(W)|| = 2.802677
# Iteration = 9, ||gradL(W)|| = 2.802677
# Iteration = 10, ||gradL(W)|| = 2.802677
# Iteration = 11, ||gradL(W)|| = 2.802677
# Iteration = 12, ||gradL(W)|| = 2.802677
# Iteration = 13, ||gradL(W)|| = 2.802677
# Iteration = 14, ||gradL(W)|| = 2.802677
# Iteration = 15, ||gradL(W)|| = 2.802677
# Iteration = 16, ||gradL(W)|| = 2.802677
# Iteration = 17, ||gradL(W)|| = 2.802677
# Iteration = 18, ||gradL(W)|| = 2.802677
# Iteration = 19, ||gradL(W)|| = 2.802677
# Iteration = 20, ||gradL(W)|| = 2.802677
# Iteration = 21, ||gradL(W)|| = 2.802677
# Iteration = 22, ||gradL(W)|| = 2.802677
# Iteration = 23, ||gradL(W)|| = 2.802677
# Iteration = 24, ||gradL(W)|| = 2.802677
# Iteration = 25, ||gradL(W)|| = 2.802677
# Iteration = 26, ||gradL(W)|| = 2.802677
# Iteration = 27, ||gradL(W)|| = 2.802677
# Iteration = 28, ||gradL(W)|| = 2.802677
# Iteration = 29, ||gradL(W)|| = 2.802677
# Iteration = 30, ||gradL(W)|| = 2.802677
# Iteration = 31, ||gradL(W)|| = 2.802677
# Iteration = 32, ||gradL(W)|| = 2.802677
# Iteration = 33, ||gradL(W)|| = 2.802677
# Iteration = 34, ||gradL(W)|| = 2.802677
# Iteration = 35, ||gradL(W)|| = 2.802677
# Iteration = 36, ||gradL(W)|| = 2.802677
# Iteration = 37, ||gradL(W)|| = 2.802677
# Iteration = 38, ||gradL(W)|| = 2.802677
# Iteration = 39, ||gradL(W)|| = 2.802677
# Iteration = 40, ||gradL(W)|| = 2.802677
# Iteration = 41, ||gradL(W)|| = 2.802677
# Iteration = 42, ||gradL(W)|| = 2.802677
# Iteration = 43, ||gradL(W)|| = 2.802677
# Iteration = 44, ||gradL(W)|| = 2.802677
# Iteration = 45, ||gradL(W)|| = 2.802677
# Iteration = 46, ||gradL(W)|| = 2.802677
# Iteration = 47, ||gradL(W)|| = 2.802677
# Iteration = 48, ||gradL(W)|| = 2.802677
# Iteration = 49, ||gradL(W)|| = 2.802677
# Iteration = 50, ||gradL(W)|| = 2.802677
# Iteration = 51, ||gradL(W)|| = 2.802677
# Iteration = 52, ||gradL(W)|| = 2.802677
# Iteration = 53, ||gradL(W)|| = 2.802677
# Iteration = 54, ||gradL(W)|| = 2.802677
# Iteration = 55, ||gradL(W)|| = 2.802677
# Iteration = 56, ||gradL(W)|| = 2.802677
# Iteration = 57, ||gradL(W)|| = 2.802677
# Iteration = 58, ||gradL(W)|| = 2.802677
# Iteration = 59, ||gradL(W)|| = 2.802677
# Iteration = 60, ||gradL(W)|| = 2.802677
# Iteration = 61, ||gradL(W)|| = 2.802677
# Iteration = 62, ||gradL(W)|| = 2.802677
# Iteration = 63, ||gradL(W)|| = 2.802677
# Iteration = 64, ||gradL(W)|| = 2.802677
# Iteration = 65, ||gradL(W)|| = 2.802677
# Iteration = 66, ||gradL(W)|| = 2.802677
# Iteration = 67, ||gradL(W)|| = 2.802677
# Iteration = 68, ||gradL(W)|| = 2.802677
# Iteration = 69, ||gradL(W)|| = 2.802677
# Iteration = 70, ||gradL(W)|| = 2.802677
# Iteration = 71, ||gradL(W)|| = 2.802677
# Iteration = 72, ||gradL(W)|| = 2.802677
# Iteration = 73, ||gradL(W)|| = 2.802677
# Iteration = 74, ||gradL(W)|| = 2.802677
# Iteration = 75, ||gradL(W)|| = 2.802677
# Iteration = 76, ||gradL(W)|| = 2.802677
# Iteration = 77, ||gradL(W)|| = 2.802677
# Iteration = 78, ||gradL(W)|| = 2.802677
# Iteration = 79, ||gradL(W)|| = 2.802677
# Iteration = 80, ||gradL(W)|| = 2.802677
# Iteration = 81, ||gradL(W)|| = 2.802677
# Iteration = 82, ||gradL(W)|| = 2.802677
# Iteration = 83, ||gradL(W)|| = 2.802677
# Iteration = 84, ||gradL(W)|| = 2.802677
# Iteration = 85, ||gradL(W)|| = 2.802677
# Iteration = 86, ||gradL(W)|| = 2.802677
# Iteration = 87, ||gradL(W)|| = 2.802677
# Iteration = 88, ||gradL(W)|| = 2.802677
# Iteration = 89, ||gradL(W)|| = 2.802677
# Iteration = 90, ||gradL(W)|| = 2.802677
# Iteration = 91, ||gradL(W)|| = 2.802677
# Iteration = 92, ||gradL(W)|| = 2.802677
# Iteration = 93, ||gradL(W)|| = 2.802677
# Iteration = 94, ||gradL(W)|| = 2.802677
# Iteration = 95, ||gradL(W)|| = 2.802677
# Iteration = 96, ||gradL(W)|| = 2.802677
# Iteration = 97, ||gradL(W)|| = 2.802677
# Iteration = 98, ||gradL(W)|| = 2.802677
# Iteration = 99, ||gradL(W)|| = 2.802677
# Iteration = 100, ||gradL(W)|| = 2.802677
# Iteration = 101, ||gradL(W)|| = 2.802677
# Iteration = 102, ||gradL(W)|| = 2.802677
# Iteration = 103, ||gradL(W)|| = 2.802677
# Iteration = 104, ||gradL(W)|| = 2.802677
# Iteration = 105, ||gradL(W)|| = 2.802677
# Iteration = 106, ||gradL(W)|| = 2.802677
# Iteration = 107, ||gradL(W)|| = 2.802677
# Iteration = 108, ||gradL(W)|| = 2.802677
# Iteration = 109, ||gradL(W)|| = 2.802677
# Iteration = 110, ||gradL(W)|| = 2.802677
# Iteration = 111, ||gradL(W)|| = 2.802677
# Iteration = 112, ||gradL(W)|| = 2.802677
# Iteration = 113, ||gradL(W)|| = 2.802677
# Iteration = 114, ||gradL(W)|| = 2.802677
# Iteration = 115, ||gradL(W)|| = 2.802677
# Iteration = 116, ||gradL(W)|| = 2.802677
# Iteration = 117, ||gradL(W)|| = 2.802677
# Iteration = 118, ||gradL(W)|| = 2.802677
# Iteration = 119, ||gradL(W)|| = 2.802677
# Iteration = 120, ||gradL(W)|| = 2.802677
# Iteration = 121, ||gradL(W)|| = 2.802677
# Iteration = 122, ||gradL(W)|| = 2.802677
# Iteration = 123, ||gradL(W)|| = 2.802677
# Iteration = 124, ||gradL(W)|| = 2.802677
# Iteration = 125, ||gradL(W)|| = 2.802677
# Iteration = 126, ||gradL(W)|| = 2.802677
# Iteration = 127, ||gradL(W)|| = 2.802677
# Iteration = 128, ||gradL(W)|| = 2.802677
# Iteration = 129, ||gradL(W)|| = 2.802677
# Iteration = 130, ||gradL(W)|| = 2.802677
# Iteration = 131, ||gradL(W)|| = 2.802677
# Iteration = 132, ||gradL(W)|| = 2.802677
# Iteration = 133, ||gradL(W)|| = 2.802677
# Iteration = 134, ||gradL(W)|| = 2.802677
# Iteration = 135, ||gradL(W)|| = 2.802677
# Iteration = 136, ||gradL(W)|| = 2.802677
# Iteration = 137, ||gradL(W)|| = 2.802677
# Iteration = 138, ||gradL(W)|| = 2.802677
# Iteration = 139, ||gradL(W)|| = 2.802677
# Iteration = 140, ||gradL(W)|| = 2.802677
# Iteration = 141, ||gradL(W)|| = 2.802677
# Iteration = 142, ||gradL(W)|| = 2.802677
# Iteration = 143, ||gradL(W)|| = 2.802677
# Iteration = 144, ||gradL(W)|| = 2.802677
# Iteration = 145, ||gradL(W)|| = 2.802677
# Iteration = 146, ||gradL(W)|| = 2.802677
# Iteration = 147, ||gradL(W)|| = 2.802677
# Iteration = 148, ||gradL(W)|| = 2.802677
# Iteration = 149, ||gradL(W)|| = 2.802677
# Iteration = 150, ||gradL(W)|| = 2.802677
# Iteration = 151, ||gradL(W)|| = 2.802677
# Iteration = 152, ||gradL(W)|| = 2.802677
# Iteration = 153, ||gradL(W)|| = 2.802677
# Iteration = 154, ||gradL(W)|| = 2.802677
# Iteration = 155, ||gradL(W)|| = 2.802677
# Iteration = 156, ||gradL(W)|| = 2.802677
# Iteration = 157, ||gradL(W)|| = 2.802677
# Iteration = 158, ||gradL(W)|| = 2.802677
# Iteration = 159, ||gradL(W)|| = 2.802677
# Iteration = 160, ||gradL(W)|| = 2.802677
# Iteration = 161, ||gradL(W)|| = 2.802677
# Iteration = 162, ||gradL(W)|| = 2.802677
# Iteration = 163, ||gradL(W)|| = 2.802677
# Iteration = 164, ||gradL(W)|| = 2.802677
# Iteration = 165, ||gradL(W)|| = 2.802677
# Iteration = 166, ||gradL(W)|| = 2.802677
# Iteration = 167, ||gradL(W)|| = 2.802677
# Iteration = 168, ||gradL(W)|| = 2.802677
# Iteration = 169, ||gradL(W)|| = 2.802677
# Iteration = 170, ||gradL(W)|| = 2.802677
# Iteration = 171, ||gradL(W)|| = 2.802677
# Iteration = 172, ||gradL(W)|| = 2.802677
# Iteration = 173, ||gradL(W)|| = 2.802677
# Iteration = 174, ||gradL(W)|| = 2.802677
# Iteration = 175, ||gradL(W)|| = 2.802677
# Iteration = 176, ||gradL(W)|| = 2.802677
# Iteration = 177, ||gradL(W)|| = 2.802677
# Iteration = 178, ||gradL(W)|| = 2.802677
# Iteration = 179, ||gradL(W)|| = 2.802677
# Iteration = 180, ||gradL(W)|| = 2.802677
# Iteration = 181, ||gradL(W)|| = 2.802677
# Iteration = 182, ||gradL(W)|| = 2.802677
# Iteration = 183, ||gradL(W)|| = 2.802677
# Iteration = 184, ||gradL(W)|| = 2.802677
# Iteration = 185, ||gradL(W)|| = 2.802677
# Iteration = 186, ||gradL(W)|| = 2.802677
# Iteration = 187, ||gradL(W)|| = 2.802677
# Iteration = 188, ||gradL(W)|| = 2.802677
# Iteration = 189, ||gradL(W)|| = 2.802677
# Iteration = 190, ||gradL(W)|| = 2.802677
# Iteration = 191, ||gradL(W)|| = 2.802677
# Iteration = 192, ||gradL(W)|| = 2.802677
# Iteration = 193, ||gradL(W)|| = 2.802677
# Iteration = 194, ||gradL(W)|| = 2.802677
# Iteration = 195, ||gradL(W)|| = 2.802677
# Iteration = 196, ||gradL(W)|| = 2.802677
# Iteration = 197, ||gradL(W)|| = 2.802677
# Iteration = 198, ||gradL(W)|| = 2.802677
# Iteration = 199, ||gradL(W)|| = 2.802677
# Iteration = 200, ||gradL(W)|| = 2.802677
# Iteration = 201, ||gradL(W)|| = 2.802677
# Iteration = 202, ||gradL(W)|| = 2.802677
# Iteration = 203, ||gradL(W)|| = 2.802677
# Iteration = 204, ||gradL(W)|| = 2.802677
# Iteration = 205, ||gradL(W)|| = 2.802677
# Iteration = 206, ||gradL(W)|| = 2.802677
# Iteration = 207, ||gradL(W)|| = 2.802677
# Iteration = 208, ||gradL(W)|| = 2.802677
# Iteration = 209, ||gradL(W)|| = 2.802677
# Iteration = 210, ||gradL(W)|| = 2.802677
# Iteration = 211, ||gradL(W)|| = 2.802677
# Iteration = 212, ||gradL(W)|| = 2.802677
# Iteration = 213, ||gradL(W)|| = 2.802677
# Iteration = 214, ||gradL(W)|| = 2.802677
# Iteration = 215, ||gradL(W)|| = 2.802677
# Iteration = 216, ||gradL(W)|| = 2.802677
# Iteration = 217, ||gradL(W)|| = 2.802677
# Iteration = 218, ||gradL(W)|| = 2.802677
# Iteration = 219, ||gradL(W)|| = 2.802677
# Iteration = 220, ||gradL(W)|| = 2.802677
# Iteration = 221, ||gradL(W)|| = 2.802677
# Iteration = 222, ||gradL(W)|| = 2.802677
# Iteration = 223, ||gradL(W)|| = 2.802677
# Iteration = 224, ||gradL(W)|| = 2.802677
# Iteration = 225, ||gradL(W)|| = 2.802677
# Iteration = 226, ||gradL(W)|| = 2.802677
# Iteration = 227, ||gradL(W)|| = 2.802677
# Iteration = 228, ||gradL(W)|| = 2.802677
# Iteration = 229, ||gradL(W)|| = 2.802677
# Iteration = 230, ||gradL(W)|| = 2.802677
# Iteration = 231, ||gradL(W)|| = 2.802677
# Iteration = 232, ||gradL(W)|| = 2.802677
# Iteration = 233, ||gradL(W)|| = 2.802677
# Iteration = 234, ||gradL(W)|| = 2.802677
# Iteration = 235, ||gradL(W)|| = 2.802677
# Iteration = 236, ||gradL(W)|| = 2.802677
# Iteration = 237, ||gradL(W)|| = 2.802677
# Iteration = 238, ||gradL(W)|| = 2.802677
# Iteration = 239, ||gradL(W)|| = 2.802677
# Iteration = 240, ||gradL(W)|| = 2.802677
# Iteration = 241, ||gradL(W)|| = 2.802677
# Iteration = 242, ||gradL(W)|| = 2.802677
# Iteration = 243, ||gradL(W)|| = 2.802677
# Iteration = 244, ||gradL(W)|| = 2.802677
# Iteration = 245, ||gradL(W)|| = 2.802677
# Iteration = 246, ||gradL(W)|| = 2.802677
# Iteration = 247, ||gradL(W)|| = 2.802677
# Iteration = 248, ||gradL(W)|| = 2.802677
# Iteration = 249, ||gradL(W)|| = 2.802677
# Iteration = 250, ||gradL(W)|| = 2.802677
# Iteration = 251, ||gradL(W)|| = 2.802677
# Iteration = 252, ||gradL(W)|| = 2.802677
# Iteration = 253, ||gradL(W)|| = 2.802677
# Iteration = 254, ||gradL(W)|| = 2.802677
# Iteration = 255, ||gradL(W)|| = 2.802677
# Iteration = 256, ||gradL(W)|| = 2.802677
# Iteration = 257, ||gradL(W)|| = 2.802677
# Iteration = 258, ||gradL(W)|| = 2.802677
# Iteration = 259, ||gradL(W)|| = 2.802677
# Iteration = 260, ||gradL(W)|| = 2.802677
# Iteration = 261, ||gradL(W)|| = 2.802677
# Iteration = 262, ||gradL(W)|| = 2.802677
# Iteration = 263, ||gradL(W)|| = 2.802677
# Iteration = 264, ||gradL(W)|| = 2.802677
# Iteration = 265, ||gradL(W)|| = 2.802677
# Iteration = 266, ||gradL(W)|| = 2.802677
# Iteration = 267, ||gradL(W)|| = 2.802677
# Iteration = 268, ||gradL(W)|| = 2.802677
# Iteration = 269, ||gradL(W)|| = 2.802677
# Iteration = 270, ||gradL(W)|| = 2.802677
# Iteration = 271, ||gradL(W)|| = 2.802677
# Iteration = 272, ||gradL(W)|| = 2.802677
# Iteration = 273, ||gradL(W)|| = 2.802677
# Iteration = 274, ||gradL(W)|| = 2.802677
# Iteration = 275, ||gradL(W)|| = 2.802677
# Iteration = 276, ||gradL(W)|| = 2.802677
# Iteration = 277, ||gradL(W)|| = 2.802677
# Iteration = 278, ||gradL(W)|| = 2.802677
# Iteration = 279, ||gradL(W)|| = 2.802677
# Iteration = 280, ||gradL(W)|| = 2.802677
# Iteration = 281, ||gradL(W)|| = 2.802677
# Iteration = 282, ||gradL(W)|| = 2.802677
# Iteration = 283, ||gradL(W)|| = 2.802677
# Iteration = 284, ||gradL(W)|| = 2.802677
# Iteration = 285, ||gradL(W)|| = 2.802677
# Iteration = 286, ||gradL(W)|| = 2.802677
# Iteration = 287, ||gradL(W)|| = 2.802677
# Iteration = 288, ||gradL(W)|| = 2.802677
# Iteration = 289, ||gradL(W)|| = 2.802677
# Iteration = 290, ||gradL(W)|| = 2.802677
# Iteration = 291, ||gradL(W)|| = 2.802677
# Iteration = 292, ||gradL(W)|| = 2.802677
# Iteration = 293, ||gradL(W)|| = 2.802677
# Iteration = 294, ||gradL(W)|| = 2.802677
# Iteration = 295, ||gradL(W)|| = 2.802677
# Iteration = 296, ||gradL(W)|| = 2.802677
# Iteration = 297, ||gradL(W)|| = 2.802677
# Iteration = 298, ||gradL(W)|| = 2.802677
# Iteration = 299, ||gradL(W)|| = 2.802677
# Iteration = 300, ||gradL(W)|| = 2.802677
# Iteration = 301, ||gradL(W)|| = 2.802677
# Iteration = 302, ||gradL(W)|| = 2.802677
# Iteration = 303, ||gradL(W)|| = 2.802677
# Iteration = 304, ||gradL(W)|| = 2.802677
# Iteration = 305, ||gradL(W)|| = 2.802677
# Iteration = 306, ||gradL(W)|| = 2.802677
# Iteration = 307, ||gradL(W)|| = 2.802677
# Iteration = 308, ||gradL(W)|| = 2.802677
# Iteration = 309, ||gradL(W)|| = 2.802677
# Iteration = 310, ||gradL(W)|| = 2.802677
# Iteration = 311, ||gradL(W)|| = 2.802677
# Iteration = 312, ||gradL(W)|| = 2.802677
# Iteration = 313, ||gradL(W)|| = 2.802677
# Iteration = 314, ||gradL(W)|| = 2.802677
# Iteration = 315, ||gradL(W)|| = 2.802677
# Iteration = 316, ||gradL(W)|| = 2.802677
# Iteration = 317, ||gradL(W)|| = 2.802677
# Iteration = 318, ||gradL(W)|| = 2.802677
# Iteration = 319, ||gradL(W)|| = 2.802677
# Iteration = 320, ||gradL(W)|| = 2.802677
# Iteration = 321, ||gradL(W)|| = 2.802677
# Iteration = 322, ||gradL(W)|| = 2.802677
# Iteration = 323, ||gradL(W)|| = 2.802677
# Iteration = 324, ||gradL(W)|| = 2.802677
# Iteration = 325, ||gradL(W)|| = 2.802677
# Iteration = 326, ||gradL(W)|| = 2.802677
# Iteration = 327, ||gradL(W)|| = 2.802677
# Iteration = 328, ||gradL(W)|| = 2.802677
# Iteration = 329, ||gradL(W)|| = 2.802677
# Iteration = 330, ||gradL(W)|| = 2.802677
# Iteration = 331, ||gradL(W)|| = 2.802677
# Iteration = 332, ||gradL(W)|| = 2.802677
# Iteration = 333, ||gradL(W)|| = 2.802677
# Iteration = 334, ||gradL(W)|| = 2.802677
# Iteration = 335, ||gradL(W)|| = 2.802677
# Iteration = 336, ||gradL(W)|| = 2.802677
# Iteration = 337, ||gradL(W)|| = 2.802677
# Iteration = 338, ||gradL(W)|| = 2.802677
# Iteration = 339, ||gradL(W)|| = 2.802677
# Iteration = 340, ||gradL(W)|| = 2.802677
# Iteration = 341, ||gradL(W)|| = 2.802677
# Iteration = 342, ||gradL(W)|| = 2.802677
# Iteration = 343, ||gradL(W)|| = 2.802677
# Iteration = 344, ||gradL(W)|| = 2.802677
# Iteration = 345, ||gradL(W)|| = 2.802677
# Iteration = 346, ||gradL(W)|| = 2.802677
# Iteration = 347, ||gradL(W)|| = 2.802677
# Iteration = 348, ||gradL(W)|| = 2.802677
# Iteration = 349, ||gradL(W)|| = 2.802677
# Iteration = 350, ||gradL(W)|| = 2.802677
# Iteration = 351, ||gradL(W)|| = 2.802677
# Iteration = 352, ||gradL(W)|| = 2.802677
# Iteration = 353, ||gradL(W)|| = 2.802677
# Iteration = 354, ||gradL(W)|| = 2.802677
# Iteration = 355, ||gradL(W)|| = 2.802677
# Iteration = 356, ||gradL(W)|| = 2.802677
# Iteration = 357, ||gradL(W)|| = 2.802677
# Iteration = 358, ||gradL(W)|| = 2.802677
# Iteration = 359, ||gradL(W)|| = 2.802677
# Iteration = 360, ||gradL(W)|| = 2.802677
# Iteration = 361, ||gradL(W)|| = 2.802677
# Iteration = 362, ||gradL(W)|| = 2.802677
# Iteration = 363, ||gradL(W)|| = 2.802677
# Iteration = 364, ||gradL(W)|| = 2.802677
# Iteration = 365, ||gradL(W)|| = 2.802677
# Iteration = 366, ||gradL(W)|| = 2.802677
# Iteration = 367, ||gradL(W)|| = 2.802677
# Iteration = 368, ||gradL(W)|| = 2.802677
# Iteration = 369, ||gradL(W)|| = 2.802677
# Iteration = 370, ||gradL(W)|| = 2.802677
# Iteration = 371, ||gradL(W)|| = 2.802677
# Iteration = 372, ||gradL(W)|| = 2.802677
# Iteration = 373, ||gradL(W)|| = 2.802677
# Iteration = 374, ||gradL(W)|| = 2.802677
# Iteration = 375, ||gradL(W)|| = 2.802677
# Iteration = 376, ||gradL(W)|| = 2.802677
# Iteration = 377, ||gradL(W)|| = 2.802677
# Iteration = 378, ||gradL(W)|| = 2.802677
# Iteration = 379, ||gradL(W)|| = 2.802677
# Iteration = 380, ||gradL(W)|| = 2.802677
# Iteration = 381, ||gradL(W)|| = 2.802677
# Iteration = 382, ||gradL(W)|| = 2.802677
# Iteration = 383, ||gradL(W)|| = 2.802677
# Iteration = 384, ||gradL(W)|| = 2.802677
# Iteration = 385, ||gradL(W)|| = 2.802677
# Iteration = 386, ||gradL(W)|| = 2.802677
# Iteration = 387, ||gradL(W)|| = 2.802677
# Iteration = 388, ||gradL(W)|| = 2.802677
# Iteration = 389, ||gradL(W)|| = 2.802677
# Iteration = 390, ||gradL(W)|| = 2.802677
# Iteration = 391, ||gradL(W)|| = 2.802677
# Iteration = 392, ||gradL(W)|| = 2.802677
# Iteration = 393, ||gradL(W)|| = 2.802677
# Iteration = 394, ||gradL(W)|| = 2.802677
# Iteration = 395, ||gradL(W)|| = 2.802677
# Iteration = 396, ||gradL(W)|| = 2.802677
# Iteration = 397, ||gradL(W)|| = 2.802677
# Iteration = 398, ||gradL(W)|| = 2.802677
# Iteration = 399, ||gradL(W)|| = 2.802677
# Iteration = 400, ||gradL(W)|| = 2.802677
# Iteration = 401, ||gradL(W)|| = 2.802677
# Iteration = 402, ||gradL(W)|| = 2.802677
# Iteration = 403, ||gradL(W)|| = 2.802677
# Iteration = 404, ||gradL(W)|| = 2.802677
# Iteration = 405, ||gradL(W)|| = 2.802677
# Iteration = 406, ||gradL(W)|| = 2.802677
# Iteration = 407, ||gradL(W)|| = 2.802677
# Iteration = 408, ||gradL(W)|| = 2.802677
# Iteration = 409, ||gradL(W)|| = 2.802677
# Iteration = 410, ||gradL(W)|| = 2.802677
# Iteration = 411, ||gradL(W)|| = 2.802677
# Iteration = 412, ||gradL(W)|| = 2.802677
# Iteration = 413, ||gradL(W)|| = 2.802677
# Iteration = 414, ||gradL(W)|| = 2.802677
# Iteration = 415, ||gradL(W)|| = 2.802677
# Iteration = 416, ||gradL(W)|| = 2.802677
# Iteration = 417, ||gradL(W)|| = 2.802677
# Iteration = 418, ||gradL(W)|| = 2.802677
# Iteration = 419, ||gradL(W)|| = 2.802677
# Iteration = 420, ||gradL(W)|| = 2.802677
# Iteration = 421, ||gradL(W)|| = 2.802677
# Iteration = 422, ||gradL(W)|| = 2.802677
# Iteration = 423, ||gradL(W)|| = 2.802677
# Iteration = 424, ||gradL(W)|| = 2.802677
# Iteration = 425, ||gradL(W)|| = 2.802677
# Iteration = 426, ||gradL(W)|| = 2.802677
# Iteration = 427, ||gradL(W)|| = 2.802677
# Iteration = 428, ||gradL(W)|| = 2.802677
# Iteration = 429, ||gradL(W)|| = 2.802677
# Iteration = 430, ||gradL(W)|| = 2.802677
# Iteration = 431, ||gradL(W)|| = 2.802677
# Iteration = 432, ||gradL(W)|| = 2.802677
# Iteration = 433, ||gradL(W)|| = 2.802677
# Iteration = 434, ||gradL(W)|| = 2.802677
# Iteration = 435, ||gradL(W)|| = 2.802677
# Iteration = 436, ||gradL(W)|| = 2.802677
# Iteration = 437, ||gradL(W)|| = 2.802677
# Iteration = 438, ||gradL(W)|| = 2.802677
# Iteration = 439, ||gradL(W)|| = 2.802677
# Iteration = 440, ||gradL(W)|| = 2.802677
# Iteration = 441, ||gradL(W)|| = 2.802677
# Iteration = 442, ||gradL(W)|| = 2.802677
# Iteration = 443, ||gradL(W)|| = 2.802677
# Iteration = 444, ||gradL(W)|| = 2.802677
# Iteration = 445, ||gradL(W)|| = 2.802677
# Iteration = 446, ||gradL(W)|| = 2.802677
# Iteration = 447, ||gradL(W)|| = 2.802677
# Iteration = 448, ||gradL(W)|| = 2.802677
# Iteration = 449, ||gradL(W)|| = 2.802677
# Iteration = 450, ||gradL(W)|| = 2.802677
# Iteration = 451, ||gradL(W)|| = 2.802677
# Iteration = 452, ||gradL(W)|| = 2.802677
# Iteration = 453, ||gradL(W)|| = 2.802677
# Iteration = 454, ||gradL(W)|| = 2.802677
# Iteration = 455, ||gradL(W)|| = 2.802677
# Iteration = 456, ||gradL(W)|| = 2.802677
# Iteration = 457, ||gradL(W)|| = 2.802677
# Iteration = 458, ||gradL(W)|| = 2.802677
# Iteration = 459, ||gradL(W)|| = 2.802677
# Iteration = 460, ||gradL(W)|| = 2.802677
# Iteration = 461, ||gradL(W)|| = 2.802677
# Iteration = 462, ||gradL(W)|| = 2.802677
# Iteration = 463, ||gradL(W)|| = 2.802677
# Iteration = 464, ||gradL(W)|| = 2.802677
# Iteration = 465, ||gradL(W)|| = 2.802677
# Iteration = 466, ||gradL(W)|| = 2.802677
# Iteration = 467, ||gradL(W)|| = 2.802677
# Iteration = 468, ||gradL(W)|| = 2.802677
# Iteration = 469, ||gradL(W)|| = 2.802677
# Iteration = 470, ||gradL(W)|| = 2.802677
# Iteration = 471, ||gradL(W)|| = 2.802677
# Iteration = 472, ||gradL(W)|| = 2.802677
# Iteration = 473, ||gradL(W)|| = 2.802677
# Iteration = 474, ||gradL(W)|| = 2.802677
# Iteration = 475, ||gradL(W)|| = 2.802677
# Iteration = 476, ||gradL(W)|| = 2.802677
# Iteration = 477, ||gradL(W)|| = 2.802677
# Iteration = 478, ||gradL(W)|| = 2.802677
# Iteration = 479, ||gradL(W)|| = 2.802677
# Iteration = 480, ||gradL(W)|| = 2.802677
# Iteration = 481, ||gradL(W)|| = 2.802677
# Iteration = 482, ||gradL(W)|| = 2.802677
# Iteration = 483, ||gradL(W)|| = 2.802677
# Iteration = 484, ||gradL(W)|| = 2.802677
# Iteration = 485, ||gradL(W)|| = 2.802677
# Iteration = 486, ||gradL(W)|| = 2.802677
# Iteration = 487, ||gradL(W)|| = 2.802677
# Iteration = 488, ||gradL(W)|| = 2.802677
# Iteration = 489, ||gradL(W)|| = 2.802677
# Iteration = 490, ||gradL(W)|| = 2.802677
# Iteration = 491, ||gradL(W)|| = 2.802677
# Iteration = 492, ||gradL(W)|| = 2.802677
# Iteration = 493, ||gradL(W)|| = 2.802677
# Iteration = 494, ||gradL(W)|| = 2.802677
# Iteration = 495, ||gradL(W)|| = 2.802677
# Iteration = 496, ||gradL(W)|| = 2.802677
# Iteration = 497, ||gradL(W)|| = 2.802677
# Iteration = 498, ||gradL(W)|| = 2.802677
# Iteration = 499, ||gradL(W)|| = 2.802677
# Iteration = 500, ||gradL(W)|| = 2.802677
# Iteration = 501, ||gradL(W)|| = 2.802677
# Iteration = 502, ||gradL(W)|| = 2.802677
# Iteration = 503, ||gradL(W)|| = 2.802677
# Iteration = 504, ||gradL(W)|| = 2.802677
# Iteration = 505, ||gradL(W)|| = 2.802677
# Iteration = 506, ||gradL(W)|| = 2.802677
# Iteration = 507, ||gradL(W)|| = 2.802677
# Iteration = 508, ||gradL(W)|| = 2.802677
# Iteration = 509, ||gradL(W)|| = 2.802677
# Iteration = 510, ||gradL(W)|| = 2.802677
# Iteration = 511, ||gradL(W)|| = 2.802677
# Iteration = 512, ||gradL(W)|| = 2.802677
# Iteration = 513, ||gradL(W)|| = 2.802677
# Iteration = 514, ||gradL(W)|| = 2.802677
# Iteration = 515, ||gradL(W)|| = 2.802677
# Iteration = 516, ||gradL(W)|| = 2.802677
# Iteration = 517, ||gradL(W)|| = 2.802677
# Iteration = 518, ||gradL(W)|| = 2.802677
# Iteration = 519, ||gradL(W)|| = 2.802677
# Iteration = 520, ||gradL(W)|| = 2.802677
# Iteration = 521, ||gradL(W)|| = 2.802677
# Iteration = 522, ||gradL(W)|| = 2.802677
# Iteration = 523, ||gradL(W)|| = 2.802677
# Iteration = 524, ||gradL(W)|| = 2.802677
# Iteration = 525, ||gradL(W)|| = 2.802677
# Iteration = 526, ||gradL(W)|| = 2.802677
# Iteration = 527, ||gradL(W)|| = 2.802677
# Iteration = 528, ||gradL(W)|| = 2.802677
# Iteration = 529, ||gradL(W)|| = 2.802677
# Iteration = 530, ||gradL(W)|| = 2.802677
# Iteration = 531, ||gradL(W)|| = 2.802677
# Iteration = 532, ||gradL(W)|| = 2.802677
# Iteration = 533, ||gradL(W)|| = 2.802677
# Iteration = 534, ||gradL(W)|| = 2.802677
# Iteration = 535, ||gradL(W)|| = 2.802677
# Iteration = 536, ||gradL(W)|| = 2.802677
# Iteration = 537, ||gradL(W)|| = 2.802677
# Iteration = 538, ||gradL(W)|| = 2.802677
# Iteration = 539, ||gradL(W)|| = 2.802677
# Iteration = 540, ||gradL(W)|| = 2.802677
# Iteration = 541, ||gradL(W)|| = 2.802677
# Iteration = 542, ||gradL(W)|| = 2.802677
# Iteration = 543, ||gradL(W)|| = 2.802677
# Iteration = 544, ||gradL(W)|| = 2.802677
# Iteration = 545, ||gradL(W)|| = 2.802677
# Iteration = 546, ||gradL(W)|| = 2.802677
# Iteration = 547, ||gradL(W)|| = 2.802677
# Iteration = 548, ||gradL(W)|| = 2.802677
# Iteration = 549, ||gradL(W)|| = 2.802677
# Iteration = 550, ||gradL(W)|| = 2.802677
# Iteration = 551, ||gradL(W)|| = 2.802677
# Iteration = 552, ||gradL(W)|| = 2.802677
# Iteration = 553, ||gradL(W)|| = 2.802677
# Iteration = 554, ||gradL(W)|| = 2.802677
# Iteration = 555, ||gradL(W)|| = 2.802677
# Iteration = 556, ||gradL(W)|| = 2.802677
# Iteration = 557, ||gradL(W)|| = 2.802677
# Iteration = 558, ||gradL(W)|| = 2.802677
# Iteration = 559, ||gradL(W)|| = 2.802677
# Iteration = 560, ||gradL(W)|| = 2.802677
# Iteration = 561, ||gradL(W)|| = 2.802677
# Iteration = 562, ||gradL(W)|| = 2.802677
# Iteration = 563, ||gradL(W)|| = 2.802677
# Iteration = 564, ||gradL(W)|| = 2.802677
# Iteration = 565, ||gradL(W)|| = 2.802677
# Iteration = 566, ||gradL(W)|| = 2.802677
# Iteration = 567, ||gradL(W)|| = 2.802677
# Iteration = 568, ||gradL(W)|| = 2.802677
# Iteration = 569, ||gradL(W)|| = 2.802677
# Iteration = 570, ||gradL(W)|| = 2.802677
# Iteration = 571, ||gradL(W)|| = 2.802677
# Iteration = 572, ||gradL(W)|| = 2.802677
# Iteration = 573, ||gradL(W)|| = 2.802677
# Iteration = 574, ||gradL(W)|| = 2.802677
# Iteration = 575, ||gradL(W)|| = 2.802677
# Iteration = 576, ||gradL(W)|| = 2.802677
# Iteration = 577, ||gradL(W)|| = 2.802677
# Iteration = 578, ||gradL(W)|| = 2.802677
# Iteration = 579, ||gradL(W)|| = 2.802677
# Iteration = 580, ||gradL(W)|| = 2.802677
# Iteration = 581, ||gradL(W)|| = 2.802677
# Iteration = 582, ||gradL(W)|| = 2.802677
# Iteration = 583, ||gradL(W)|| = 2.802677
# Iteration = 584, ||gradL(W)|| = 2.802677
# Iteration = 585, ||gradL(W)|| = 2.802677
# Iteration = 586, ||gradL(W)|| = 2.802677
# Iteration = 587, ||gradL(W)|| = 2.802677
# Iteration = 588, ||gradL(W)|| = 2.802677
# Iteration = 589, ||gradL(W)|| = 2.802677
# Iteration = 590, ||gradL(W)|| = 2.802677
# Iteration = 591, ||gradL(W)|| = 2.802677
# Iteration = 592, ||gradL(W)|| = 2.802677
# Iteration = 593, ||gradL(W)|| = 2.802677
# Iteration = 594, ||gradL(W)|| = 2.802677
# Iteration = 595, ||gradL(W)|| = 2.802677
# Iteration = 596, ||gradL(W)|| = 2.802677
# Iteration = 597, ||gradL(W)|| = 2.802677
# Iteration = 598, ||gradL(W)|| = 2.802677
# Iteration = 599, ||gradL(W)|| = 2.802677
# Iteration = 600, ||gradL(W)|| = 2.802677
# Iteration = 601, ||gradL(W)|| = 2.802677
# Iteration = 602, ||gradL(W)|| = 2.802677
# Iteration = 603, ||gradL(W)|| = 2.802677
# Iteration = 604, ||gradL(W)|| = 2.802677
# Iteration = 605, ||gradL(W)|| = 2.802677
# Iteration = 606, ||gradL(W)|| = 2.802677
# Iteration = 607, ||gradL(W)|| = 2.802677
# Iteration = 608, ||gradL(W)|| = 2.802677
# Iteration = 609, ||gradL(W)|| = 2.802677
# Iteration = 610, ||gradL(W)|| = 2.802677
# Iteration = 611, ||gradL(W)|| = 2.802677
# Iteration = 612, ||gradL(W)|| = 2.802677
# Iteration = 613, ||gradL(W)|| = 2.802677
# Iteration = 614, ||gradL(W)|| = 2.802677
# Iteration = 615, ||gradL(W)|| = 2.802677
# Iteration = 616, ||gradL(W)|| = 2.802677
# Iteration = 617, ||gradL(W)|| = 2.802677
# Iteration = 618, ||gradL(W)|| = 2.802677
# Iteration = 619, ||gradL(W)|| = 2.802677
# Iteration = 620, ||gradL(W)|| = 2.802677
# Iteration = 621, ||gradL(W)|| = 2.802677
# Iteration = 622, ||gradL(W)|| = 2.802677
# Iteration = 623, ||gradL(W)|| = 2.802677
# Iteration = 624, ||gradL(W)|| = 2.802677
# Iteration = 625, ||gradL(W)|| = 2.802677
# Iteration = 626, ||gradL(W)|| = 2.802677
# Iteration = 627, ||gradL(W)|| = 2.802677
# Iteration = 628, ||gradL(W)|| = 2.802677
# Iteration = 629, ||gradL(W)|| = 2.802677
# Iteration = 630, ||gradL(W)|| = 2.802677
# Iteration = 631, ||gradL(W)|| = 2.802677
# Iteration = 632, ||gradL(W)|| = 2.802677
# Iteration = 633, ||gradL(W)|| = 2.802677
# Iteration = 634, ||gradL(W)|| = 2.802677
# Iteration = 635, ||gradL(W)|| = 2.802677
# Iteration = 636, ||gradL(W)|| = 2.802677
# Iteration = 637, ||gradL(W)|| = 2.802677
# Iteration = 638, ||gradL(W)|| = 2.802677
# Iteration = 639, ||gradL(W)|| = 2.802677
# Iteration = 640, ||gradL(W)|| = 2.802677
# Iteration = 641, ||gradL(W)|| = 2.802677
# Iteration = 642, ||gradL(W)|| = 2.802677
# Iteration = 643, ||gradL(W)|| = 2.802677
# Iteration = 644, ||gradL(W)|| = 2.802677
# Iteration = 645, ||gradL(W)|| = 2.802677
# Iteration = 646, ||gradL(W)|| = 2.802677
# Iteration = 647, ||gradL(W)|| = 2.802677
# Iteration = 648, ||gradL(W)|| = 2.802677
# Iteration = 649, ||gradL(W)|| = 2.802677
# Iteration = 650, ||gradL(W)|| = 2.802677
# Iteration = 651, ||gradL(W)|| = 2.802677
# Iteration = 652, ||gradL(W)|| = 2.802677
# Iteration = 653, ||gradL(W)|| = 2.802677
# Iteration = 654, ||gradL(W)|| = 2.802677
# Iteration = 655, ||gradL(W)|| = 2.802677
# Iteration = 656, ||gradL(W)|| = 2.802677
# Iteration = 657, ||gradL(W)|| = 2.802677
# Iteration = 658, ||gradL(W)|| = 2.802677
# Iteration = 659, ||gradL(W)|| = 2.802677
# Iteration = 660, ||gradL(W)|| = 2.802677
# Iteration = 661, ||gradL(W)|| = 2.802677
# Iteration = 662, ||gradL(W)|| = 2.802677
# Iteration = 663, ||gradL(W)|| = 2.802677
# Iteration = 664, ||gradL(W)|| = 2.802677
# Iteration = 665, ||gradL(W)|| = 2.802677
# Iteration = 666, ||gradL(W)|| = 2.802677
# Iteration = 667, ||gradL(W)|| = 2.802677
# Iteration = 668, ||gradL(W)|| = 2.802677
# Iteration = 669, ||gradL(W)|| = 2.802677
# Iteration = 670, ||gradL(W)|| = 2.802677
# Iteration = 671, ||gradL(W)|| = 2.802677
# Iteration = 672, ||gradL(W)|| = 2.802677
# Iteration = 673, ||gradL(W)|| = 2.802677
# Iteration = 674, ||gradL(W)|| = 2.802677
# Iteration = 675, ||gradL(W)|| = 2.802677
# Iteration = 676, ||gradL(W)|| = 2.802677
# Iteration = 677, ||gradL(W)|| = 2.802677
# Iteration = 678, ||gradL(W)|| = 2.802677
# Iteration = 679, ||gradL(W)|| = 2.802677
# Iteration = 680, ||gradL(W)|| = 2.802677
# Iteration = 681, ||gradL(W)|| = 2.802677
# Iteration = 682, ||gradL(W)|| = 2.802677
# Iteration = 683, ||gradL(W)|| = 2.802677
# Iteration = 684, ||gradL(W)|| = 2.802677
# Iteration = 685, ||gradL(W)|| = 2.802677
# Iteration = 686, ||gradL(W)|| = 2.802677
# Iteration = 687, ||gradL(W)|| = 2.802677
# Iteration = 688, ||gradL(W)|| = 2.802677
# Iteration = 689, ||gradL(W)|| = 2.802677
# Iteration = 690, ||gradL(W)|| = 2.802677
# Iteration = 691, ||gradL(W)|| = 2.802677
# Iteration = 692, ||gradL(W)|| = 2.802677
# Iteration = 693, ||gradL(W)|| = 2.802677
# Iteration = 694, ||gradL(W)|| = 2.802677
# Iteration = 695, ||gradL(W)|| = 2.802677
# Iteration = 696, ||gradL(W)|| = 2.802677
# Iteration = 697, ||gradL(W)|| = 2.802677
# Iteration = 698, ||gradL(W)|| = 2.802677
# Iteration = 699, ||gradL(W)|| = 2.802677
# Iteration = 700, ||gradL(W)|| = 2.802677
# Iteration = 701, ||gradL(W)|| = 2.802677
# Iteration = 702, ||gradL(W)|| = 2.802677
# Iteration = 703, ||gradL(W)|| = 2.802677
# Iteration = 704, ||gradL(W)|| = 2.802677
# Iteration = 705, ||gradL(W)|| = 2.802677
# Iteration = 706, ||gradL(W)|| = 2.802677
# Iteration = 707, ||gradL(W)|| = 2.802677
# Iteration = 708, ||gradL(W)|| = 2.802677
# Iteration = 709, ||gradL(W)|| = 2.802677
# Iteration = 710, ||gradL(W)|| = 2.802677
# Iteration = 711, ||gradL(W)|| = 2.802677
# Iteration = 712, ||gradL(W)|| = 2.802677
# Iteration = 713, ||gradL(W)|| = 2.802677
# Iteration = 714, ||gradL(W)|| = 2.802677
# Iteration = 715, ||gradL(W)|| = 2.802677
# Iteration = 716, ||gradL(W)|| = 2.802677
# Iteration = 717, ||gradL(W)|| = 2.802677
# Iteration = 718, ||gradL(W)|| = 2.802677
# Iteration = 719, ||gradL(W)|| = 2.802677
# Iteration = 720, ||gradL(W)|| = 2.802677
# Iteration = 721, ||gradL(W)|| = 2.802677
# Iteration = 722, ||gradL(W)|| = 2.802677
# Iteration = 723, ||gradL(W)|| = 2.802677
# Iteration = 724, ||gradL(W)|| = 2.802677
# Iteration = 725, ||gradL(W)|| = 2.802677
# Iteration = 726, ||gradL(W)|| = 2.802677
# Iteration = 727, ||gradL(W)|| = 2.802677
# Iteration = 728, ||gradL(W)|| = 2.802677
# Iteration = 729, ||gradL(W)|| = 2.802677
# Iteration = 730, ||gradL(W)|| = 2.802677
# Iteration = 731, ||gradL(W)|| = 2.802677
# Iteration = 732, ||gradL(W)|| = 2.802677
# Iteration = 733, ||gradL(W)|| = 2.802677
# Iteration = 734, ||gradL(W)|| = 2.802677
# Iteration = 735, ||gradL(W)|| = 2.802677
# Iteration = 736, ||gradL(W)|| = 2.802677
# Iteration = 737, ||gradL(W)|| = 2.802677
# Iteration = 738, ||gradL(W)|| = 2.802677
# Iteration = 739, ||gradL(W)|| = 2.802677
# Iteration = 740, ||gradL(W)|| = 2.802677
# Iteration = 741, ||gradL(W)|| = 2.802677
# Iteration = 742, ||gradL(W)|| = 2.802677
# Iteration = 743, ||gradL(W)|| = 2.802677
# Iteration = 744, ||gradL(W)|| = 2.802677
# Iteration = 745, ||gradL(W)|| = 2.802677
# Iteration = 746, ||gradL(W)|| = 2.802677
# Iteration = 747, ||gradL(W)|| = 2.802677
# Iteration = 748, ||gradL(W)|| = 2.802677
# Iteration = 749, ||gradL(W)|| = 2.802677
# Iteration = 750, ||gradL(W)|| = 2.802677
# Iteration = 751, ||gradL(W)|| = 2.802677
# Iteration = 752, ||gradL(W)|| = 2.802677
# Iteration = 753, ||gradL(W)|| = 2.802677
# Iteration = 754, ||gradL(W)|| = 2.802677
# Iteration = 755, ||gradL(W)|| = 2.802677
# Iteration = 756, ||gradL(W)|| = 2.802677
# Iteration = 757, ||gradL(W)|| = 2.802677
# Iteration = 758, ||gradL(W)|| = 2.802677
# Iteration = 759, ||gradL(W)|| = 2.802677
# Iteration = 760, ||gradL(W)|| = 2.802677
# Iteration = 761, ||gradL(W)|| = 2.802677
# Iteration = 762, ||gradL(W)|| = 2.802677
# Iteration = 763, ||gradL(W)|| = 2.802677
# Iteration = 764, ||gradL(W)|| = 2.802677
# Iteration = 765, ||gradL(W)|| = 2.802677
# Iteration = 766, ||gradL(W)|| = 2.802677
# Iteration = 767, ||gradL(W)|| = 2.802677
# Iteration = 768, ||gradL(W)|| = 2.802677
# Iteration = 769, ||gradL(W)|| = 2.802677
# Iteration = 770, ||gradL(W)|| = 2.802677
# Iteration = 771, ||gradL(W)|| = 2.802677
# Iteration = 772, ||gradL(W)|| = 2.802677
# Iteration = 773, ||gradL(W)|| = 2.802677
# Iteration = 774, ||gradL(W)|| = 2.802677
# Iteration = 775, ||gradL(W)|| = 2.802677
# Iteration = 776, ||gradL(W)|| = 2.802677
# Iteration = 777, ||gradL(W)|| = 2.802677
# Iteration = 778, ||gradL(W)|| = 2.802677
# Iteration = 779, ||gradL(W)|| = 2.802677
# Iteration = 780, ||gradL(W)|| = 2.802677
# Iteration = 781, ||gradL(W)|| = 2.802677
# Iteration = 782, ||gradL(W)|| = 2.802677
# Iteration = 783, ||gradL(W)|| = 2.802677
# Iteration = 784, ||gradL(W)|| = 2.802677
# Iteration = 785, ||gradL(W)|| = 2.802677
# Iteration = 786, ||gradL(W)|| = 2.802677
# Iteration = 787, ||gradL(W)|| = 2.802677
# Iteration = 788, ||gradL(W)|| = 2.802677
# Iteration = 789, ||gradL(W)|| = 2.802677
# Iteration = 790, ||gradL(W)|| = 2.802677
# Iteration = 791, ||gradL(W)|| = 2.802677
# Iteration = 792, ||gradL(W)|| = 2.802677
# Iteration = 793, ||gradL(W)|| = 2.802677
# Iteration = 794, ||gradL(W)|| = 2.802677
# Iteration = 795, ||gradL(W)|| = 2.802677
# Iteration = 796, ||gradL(W)|| = 2.802677
# Iteration = 797, ||gradL(W)|| = 2.802677
# Iteration = 798, ||gradL(W)|| = 2.802677
# Iteration = 799, ||gradL(W)|| = 2.802677
# Iteration = 800, ||gradL(W)|| = 2.802677
# Iteration = 801, ||gradL(W)|| = 2.802677
# Iteration = 802, ||gradL(W)|| = 2.802677
# Iteration = 803, ||gradL(W)|| = 2.802677
# Iteration = 804, ||gradL(W)|| = 2.802677
# Iteration = 805, ||gradL(W)|| = 2.802677
# Iteration = 806, ||gradL(W)|| = 2.802677
# Iteration = 807, ||gradL(W)|| = 2.802677
# Iteration = 808, ||gradL(W)|| = 2.802677
# Iteration = 809, ||gradL(W)|| = 2.802677
# Iteration = 810, ||gradL(W)|| = 2.802677
# Iteration = 811, ||gradL(W)|| = 2.802677
# Iteration = 812, ||gradL(W)|| = 2.802677
# Iteration = 813, ||gradL(W)|| = 2.802677
# Iteration = 814, ||gradL(W)|| = 2.802677
# Iteration = 815, ||gradL(W)|| = 2.802677
# Iteration = 816, ||gradL(W)|| = 2.802677
# Iteration = 817, ||gradL(W)|| = 2.802677
# Iteration = 818, ||gradL(W)|| = 2.802677
# Iteration = 819, ||gradL(W)|| = 2.802677
# Iteration = 820, ||gradL(W)|| = 2.802677
# Iteration = 821, ||gradL(W)|| = 2.802677
# Iteration = 822, ||gradL(W)|| = 2.802677
# Iteration = 823, ||gradL(W)|| = 2.802677
# Iteration = 824, ||gradL(W)|| = 2.802677
# Iteration = 825, ||gradL(W)|| = 2.802677
# Iteration = 826, ||gradL(W)|| = 2.802677
# Iteration = 827, ||gradL(W)|| = 2.802677
# Iteration = 828, ||gradL(W)|| = 2.802677
# Iteration = 829, ||gradL(W)|| = 2.802677
# Iteration = 830, ||gradL(W)|| = 2.802677
# Iteration = 831, ||gradL(W)|| = 2.802677
# Iteration = 832, ||gradL(W)|| = 2.802677
# Iteration = 833, ||gradL(W)|| = 2.802677
# Iteration = 834, ||gradL(W)|| = 2.802677
# Iteration = 835, ||gradL(W)|| = 2.802677
# Iteration = 836, ||gradL(W)|| = 2.802677
# Iteration = 837, ||gradL(W)|| = 2.802677
# Iteration = 838, ||gradL(W)|| = 2.802677
# Iteration = 839, ||gradL(W)|| = 2.802677
# Iteration = 840, ||gradL(W)|| = 2.802677
# Iteration = 841, ||gradL(W)|| = 2.802677
# Iteration = 842, ||gradL(W)|| = 2.802677
# Iteration = 843, ||gradL(W)|| = 2.802677
# Iteration = 844, ||gradL(W)|| = 2.802677
# Iteration = 845, ||gradL(W)|| = 2.802677
# Iteration = 846, ||gradL(W)|| = 2.802677
# Iteration = 847, ||gradL(W)|| = 2.802677
# Iteration = 848, ||gradL(W)|| = 2.802677
# Iteration = 849, ||gradL(W)|| = 2.802677
# Iteration = 850, ||gradL(W)|| = 2.802677
# Iteration = 851, ||gradL(W)|| = 2.802677
# Iteration = 852, ||gradL(W)|| = 2.802677
# Iteration = 853, ||gradL(W)|| = 2.802677
# Iteration = 854, ||gradL(W)|| = 2.802677
# Iteration = 855, ||gradL(W)|| = 2.802677
# Iteration = 856, ||gradL(W)|| = 2.802677
# Iteration = 857, ||gradL(W)|| = 2.802677
# Iteration = 858, ||gradL(W)|| = 2.802677
# Iteration = 859, ||gradL(W)|| = 2.802677
# Iteration = 860, ||gradL(W)|| = 2.802677
# Iteration = 861, ||gradL(W)|| = 2.802677
# Iteration = 862, ||gradL(W)|| = 2.802677
# Iteration = 863, ||gradL(W)|| = 2.802677
# Iteration = 864, ||gradL(W)|| = 2.802677
# Iteration = 865, ||gradL(W)|| = 2.802677
# Iteration = 866, ||gradL(W)|| = 2.802677
# Iteration = 867, ||gradL(W)|| = 2.802677
# Iteration = 868, ||gradL(W)|| = 2.802677
# Iteration = 869, ||gradL(W)|| = 2.802677
# Iteration = 870, ||gradL(W)|| = 2.802677
# Iteration = 871, ||gradL(W)|| = 2.802677
# Iteration = 872, ||gradL(W)|| = 2.802677
# Iteration = 873, ||gradL(W)|| = 2.802677
# Iteration = 874, ||gradL(W)|| = 2.802677
# Iteration = 875, ||gradL(W)|| = 2.802677
# Iteration = 876, ||gradL(W)|| = 2.802677
# Iteration = 877, ||gradL(W)|| = 2.802677
# Iteration = 878, ||gradL(W)|| = 2.802677
# Iteration = 879, ||gradL(W)|| = 2.802677
# Iteration = 880, ||gradL(W)|| = 2.802677
# Iteration = 881, ||gradL(W)|| = 2.802677
# Iteration = 882, ||gradL(W)|| = 2.802677
# Iteration = 883, ||gradL(W)|| = 2.802677
# Iteration = 884, ||gradL(W)|| = 2.802677
# Iteration = 885, ||gradL(W)|| = 2.802677
# Iteration = 886, ||gradL(W)|| = 2.802677
# Iteration = 887, ||gradL(W)|| = 2.802677
# Iteration = 888, ||gradL(W)|| = 2.802677
# Iteration = 889, ||gradL(W)|| = 2.802677
# Iteration = 890, ||gradL(W)|| = 2.802677
# Iteration = 891, ||gradL(W)|| = 2.802677
# Iteration = 892, ||gradL(W)|| = 2.802677
# Iteration = 893, ||gradL(W)|| = 2.802677
# Iteration = 894, ||gradL(W)|| = 2.802677
# Iteration = 895, ||gradL(W)|| = 2.802677
# Iteration = 896, ||gradL(W)|| = 2.802677
# Iteration = 897, ||gradL(W)|| = 2.802677
# Iteration = 898, ||gradL(W)|| = 2.802677
# Iteration = 899, ||gradL(W)|| = 2.802677
# Iteration = 900, ||gradL(W)|| = 2.802677
# Iteration = 901, ||gradL(W)|| = 2.802677
# Iteration = 902, ||gradL(W)|| = 2.802677
# Iteration = 903, ||gradL(W)|| = 2.802677
# Iteration = 904, ||gradL(W)|| = 2.802677
# Iteration = 905, ||gradL(W)|| = 2.802677
# Iteration = 906, ||gradL(W)|| = 2.802677
# Iteration = 907, ||gradL(W)|| = 2.802677
# Iteration = 908, ||gradL(W)|| = 2.802677
# Iteration = 909, ||gradL(W)|| = 2.802677
# Iteration = 910, ||gradL(W)|| = 2.802677
# Iteration = 911, ||gradL(W)|| = 2.802677
# Iteration = 912, ||gradL(W)|| = 2.802677
# Iteration = 913, ||gradL(W)|| = 2.802677
# Iteration = 914, ||gradL(W)|| = 2.802677
# Iteration = 915, ||gradL(W)|| = 2.802677
# Iteration = 916, ||gradL(W)|| = 2.802677
# Iteration = 917, ||gradL(W)|| = 2.802677
# Iteration = 918, ||gradL(W)|| = 2.802677
# Iteration = 919, ||gradL(W)|| = 2.802677
# Iteration = 920, ||gradL(W)|| = 2.802677
# Iteration = 921, ||gradL(W)|| = 2.802677
# Iteration = 922, ||gradL(W)|| = 2.802677
# Iteration = 923, ||gradL(W)|| = 2.802677
# Iteration = 924, ||gradL(W)|| = 2.802677
# Iteration = 925, ||gradL(W)|| = 2.802677
# Iteration = 926, ||gradL(W)|| = 2.802677
# Iteration = 927, ||gradL(W)|| = 2.802677
# Iteration = 928, ||gradL(W)|| = 2.802677
# Iteration = 929, ||gradL(W)|| = 2.802677
# Iteration = 930, ||gradL(W)|| = 2.802677
# Iteration = 931, ||gradL(W)|| = 2.802677
# Iteration = 932, ||gradL(W)|| = 2.802677
# Iteration = 933, ||gradL(W)|| = 2.802677
# Iteration = 934, ||gradL(W)|| = 2.802677
# Iteration = 935, ||gradL(W)|| = 2.802677
# Iteration = 936, ||gradL(W)|| = 2.802677
# Iteration = 937, ||gradL(W)|| = 2.802677
# Iteration = 938, ||gradL(W)|| = 2.802677
# Iteration = 939, ||gradL(W)|| = 2.802677
# Iteration = 940, ||gradL(W)|| = 2.802677
# Iteration = 941, ||gradL(W)|| = 2.802677
# Iteration = 942, ||gradL(W)|| = 2.802677
# Iteration = 943, ||gradL(W)|| = 2.802677
# Iteration = 944, ||gradL(W)|| = 2.802677
# Iteration = 945, ||gradL(W)|| = 2.802677
# Iteration = 946, ||gradL(W)|| = 2.802677
# Iteration = 947, ||gradL(W)|| = 2.802677
# Iteration = 948, ||gradL(W)|| = 2.802677
# Iteration = 949, ||gradL(W)|| = 2.802677
# Iteration = 950, ||gradL(W)|| = 2.802677
# Iteration = 951, ||gradL(W)|| = 2.802677
# Iteration = 952, ||gradL(W)|| = 2.802677
# Iteration = 953, ||gradL(W)|| = 2.802677
# Iteration = 954, ||gradL(W)|| = 2.802677
# Iteration = 955, ||gradL(W)|| = 2.802677
# Iteration = 956, ||gradL(W)|| = 2.802677
# Iteration = 957, ||gradL(W)|| = 2.802677
# Iteration = 958, ||gradL(W)|| = 2.802677
# Iteration = 959, ||gradL(W)|| = 2.802677
# Iteration = 960, ||gradL(W)|| = 2.802677
# Iteration = 961, ||gradL(W)|| = 2.802677
# Iteration = 962, ||gradL(W)|| = 2.802677
# Iteration = 963, ||gradL(W)|| = 2.802677
# Iteration = 964, ||gradL(W)|| = 2.802677
# Iteration = 965, ||gradL(W)|| = 2.802677
# Iteration = 966, ||gradL(W)|| = 2.802677
# Iteration = 967, ||gradL(W)|| = 2.802677
# Iteration = 968, ||gradL(W)|| = 2.802677
# Iteration = 969, ||gradL(W)|| = 2.802677
# Iteration = 970, ||gradL(W)|| = 2.802677
# Iteration = 971, ||gradL(W)|| = 2.802677
# Iteration = 972, ||gradL(W)|| = 2.802677
# Iteration = 973, ||gradL(W)|| = 2.802677
# Iteration = 974, ||gradL(W)|| = 2.802677
# Iteration = 975, ||gradL(W)|| = 2.802677
# Iteration = 976, ||gradL(W)|| = 2.802677
# Iteration = 977, ||gradL(W)|| = 2.802677
# Iteration = 978, ||gradL(W)|| = 2.802677
# Iteration = 979, ||gradL(W)|| = 2.802677
# Iteration = 980, ||gradL(W)|| = 2.802677
# Iteration = 981, ||gradL(W)|| = 2.802677
# Iteration = 982, ||gradL(W)|| = 2.802677
# Iteration = 983, ||gradL(W)|| = 2.802677
# Iteration = 984, ||gradL(W)|| = 2.802677
# Iteration = 985, ||gradL(W)|| = 2.802677
# Iteration = 986, ||gradL(W)|| = 2.802677
# Iteration = 987, ||gradL(W)|| = 2.802677
# Iteration = 988, ||gradL(W)|| = 2.802677
# Iteration = 989, ||gradL(W)|| = 2.802677
# Iteration = 990, ||gradL(W)|| = 2.802677
# Iteration = 991, ||gradL(W)|| = 2.802677
# Iteration = 992, ||gradL(W)|| = 2.802677
# Iteration = 993, ||gradL(W)|| = 2.802677
# Iteration = 994, ||gradL(W)|| = 2.802677
# Iteration = 995, ||gradL(W)|| = 2.802677
# Iteration = 996, ||gradL(W)|| = 2.802677
# Iteration = 997, ||gradL(W)|| = 2.802677
# Iteration = 998, ||gradL(W)|| = 2.802677
# Iteration = 999, ||gradL(W)|| = 2.802677
# Iteration = 1000, ||gradL(W)|| = 2.802677

# %% [markdown]
# ---
#
# TensorFlow includes a low-level API known as TensorFlow core and many high-level APIs, including Keras (tf.keras).
#
# Now we will focus on the TensorFlow low-level API starting with *TensorFlow constants* (https://www.tensorflow.org/guide/tensor) which have the following proprties:
#
# 1. Values are stored at the time of defining the tensor
# 2. Immutable
#
# ---

# %%
T1 = tf.constant(5.0, dtype = tf.float16, name = 't1')
T2 = tf.constant(8.0, dtype = tf.float16, name = 't2')
T3 = tf.constant(10.0, dtype = tf.float16, name = 't3')
T4 = tf.constant([[2, 1, 4, 3], [1, 2, 3, 4], [4, 3, 2, 1]], dtype = tf.float32, name = 't4')

print(T1)
print(T2)
print(T3)
print(T4)
# Out:
# tf.Tensor(5.0, shape=(), dtype=float16)
# tf.Tensor(8.0, shape=(), dtype=float16)
# tf.Tensor(10.0, shape=(), dtype=float16)
# tf.Tensor(
# [[2. 1. 4. 3.]
#  [1. 2. 3. 4.]
#  [4. 3. 2. 1.]], shape=(3, 4), dtype=float32)

# %% [markdown]
# ---
#
# Elementwise operations on constant tensors
#
# ---

# %%
print(T1+T2)
print(T1-T2)
# Out:
# tf.Tensor(13.0, shape=(), dtype=float16)
# tf.Tensor(-3.0, shape=(), dtype=float16)

# %% [markdown]
# ---
#
# Built-in operations
#
# ---

# %%
op1 = tf.add(T1, T2)
op2 = tf.exp(T4)
print(op1)
print(op2)
# Out:
# tf.Tensor(13.0, shape=(), dtype=float16)
# tf.Tensor(
# [[ 7.39  2.72 54.6  20.09]
#  [ 2.72  7.39 20.09 54.6 ]
#  [54.6  20.09  7.39  2.72]], shape=(3, 4), dtype=float32)

# %% [markdown]
# ---
#
# TensorFlow session is applicable only for **TensorFlow version 1** which allows for defining a computation (data flow) graph such that the nodes are the operations and edges are the tensors followed by an execution of the graph.
#
# **TensorFlow version 2** has eager execution (execute immediately withut creating a session).
#
# If version 1 is to be used then, we import TensorFlow as follows:
#
# $$\begin{align*}&\texttt{import tensorflow.compat.v1 as tf}\\&\texttt{
# tf.disable_v2_behavior()}\end{align*}$$
#
# or eager execution in version 2 can be disabled using $$\begin{align*}&\texttt{import tensorflow as tf}\\&\texttt{tf.compat.v1.disable_eager_execution()}\end{align*}$$
#
# ----

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.__version__
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/compat/v2_compat.py:108: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# '2.15.0'

# %%
T1 = tf.constant(5.0, dtype = tf.float16, name = 't1')
T2 = tf.constant(8.0, dtype = tf.float16, name = 't2')
T4 = tf.constant([[2, 1, 4, 3], [1, 2, 3, 4], [4, 3, 2, 1]], dtype = tf.float32, name = 't4')
op1 = tf.add(T1, T2)
op2 = tf.exp(T4)
print(op1)
print(op2)
with tf.Session() as sess:
  print(sess.run(op1))
  print(sess.run(op2))
# Out:
# Tensor("Add:0", shape=(), dtype=float16)
# Tensor("Exp:0", shape=(3, 4), dtype=float32)
# 13.0
# [[ 7.39  2.72 54.6  20.09]
#  [ 2.72  7.39 20.09 54.6 ]
#  [54.6  20.09  7.39  2.72]]

# %% [markdown]
# ---
#
# Placeholders (applicable only for **TensorFlow version 1**):  a TensorFlow computation graph can be parameterized to accept external inputs (such as input data for a machine learning algorithm) during runtime using placeholders. That is, placeholders let are empty tensors whose values can be provided at runtime.
#
# ---

# %%
T1 = tf.placeholder(tf.float32)
T2 = tf.placeholder(tf.float32)
# Define some operations
op1 = T1 + T2
op2 = T1 * T2
with tf.Session() as sess:
  print('mutiply: ', sess.run(op1, feed_dict = {T1: 2, T2: 3}))
  print('add: ', sess.run(op2, feed_dict = {T1: 2, T2: 3}))
# Out:
# mutiply:  5.0
# add:  6.0

# %% [markdown]
# ---
#
# Re-import TensorFlow version 2
#
# ---

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.15.0'

# %% [markdown]
# ---
#
# Tensors from other Python objects such as lists, NumPy arrays, and pandas DataFrames using tf.convert_to_tensor()
#
# ---

# %%
T = tf.convert_to_tensor(np.array([1, 2, 3, 4]), dtype = tf.float64)
print(T)
# Out:
# Tensor("Const:0", shape=(4,), dtype=float64)

# %% [markdown]
# ---
#
# Variables (https://www.tensorflow.org/guide/variable)
#
# ---
